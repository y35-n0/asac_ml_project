# %%
from bs4 import BeautifulSoup
import lxml

# %%
import os
import pandas as pd
df = pd.DataFrame()

PATH = '../data/origin/dart/reports/d002/'

filenames = [filename for filename in os.listdir(PATH) if filename[-4:] == '.xml' and filename[:4] == '삼성전자']
filenames
# Out:
# ['삼성전자_d002_20200204000152.xml',
#  '삼성전자_d002_20180529000327.xml',
#  '삼성전자_d002_20200330000200.xml',
#  '삼성전자_d002_20220316000044.xml',
#  '삼성전자_d002_20220107000644.xml',
#  '삼성전자_d002_20201005000249.xml',
#  '삼성전자_d002_20200402001611.xml',
#  '삼성전자_d002_20171228000737.xml',
#  '삼성전자_d002_20210208000100.xml',
#  '삼성전자_d002_20210427000593.xml',
#  '삼성전자_d002_20180509003300.xml',
#  '삼성전자_d002_20181212000050.xml',
#  '삼성전자_d002_20201223000225.xml',
#  '삼성전자_d002_20200511000505.xml',
#  '삼성전자_d002_20180608000547.xml',
#  '삼성전자_d002_20180611000424.xml',
#  '삼성전자_d002_20221018000007.xml',
#  '삼성전자_d002_20180611000425.xml',
#  '삼성전자_d002_20190211000454.xml',
#  '삼성전자_d002_20220929000523.xml',
#  '삼성전자_d002_20201124000227.xml',
#  '삼성전자_d002_20160826000142.xml',
#  '삼성전자_d002_20220302000086.xml',
#  '삼성전자_d002_20220511000241.xml',
#  '삼성전자_d002_20211216000388.xml',
#  '삼성전자_d002_20170308000067.xml',
#  '삼성전자_d002_20180611000035.xml',
#  '삼성전자_d002_20210203000461.xml',
#  '삼성전자_d002_20210820000057.xml',
#  '삼성전자_d002_20180516000208.xml',
#  '삼성전자_d002_20180605000169.xml',
#  '삼성전자_d002_20200622000161.xml',
#  '삼성전자_d002_20220523000224.xml',
#  '삼성전자_d002_20180509000224.xml',
#  '삼성전자_d002_20180321000176.xml',
#  '삼성전자_d002_20220315000059.xml',
#  '삼성전자_d002_20220610000053.xml',
#  '삼성전자_d002_20190902000228.xml',
#  '삼성전자_d002_20171228000330.xml',
#  '삼성전자_d002_20200131000057.xml',
#  '삼성전자_d002_20151210000067.xml',
#  '삼성전자_d002_20161222000173.xml',
#  '삼성전자_d002_20150303000122.xml',
#  '삼성전자_d002_20201208000320.xml',
#  '삼성전자_d002_20160714000408.xml',
#  '삼성전자_d002_20151214000355.xml',
#  '삼성전자_d002_20151204000067.xml',
#  '삼성전자_d002_20210503000533.xml',
#  '삼성전자_d002_20201210000036.xml',
#  '삼성전자_d002_20220121000583.xml',
#  '삼성전자_d002_20201208000268.xml',
#  '삼성전자_d002_20180608000593.xml',
#  '삼성전자_d002_20210105000198.xml',
#  '삼성전자_d002_20180607000464.xml',
#  '삼성전자_d002_20150320000148.xml',
#  '삼성전자_d002_20221018000004.xml',
#  '삼성전자_d002_20200327000747.xml',
#  '삼성전자_d002_20210518000017.xml',
#  '삼성전자_d002_20220311001062.xml',
#  '삼성전자_d002_20200626000287.xml',
#  '삼성전자_d002_20201103000140.xml',
#  '삼성전자_d002_20180205000049.xml',
#  '삼성전자_d002_20210624000396.xml',
#  '삼성전자_d002_20210209000001.xml',
#  '삼성전자_d002_20160819000251.xml',
#  '삼성전자_d002_20151207000287.xml',
#  '삼성전자_d002_20180117000217.xml',
#  '삼성전자_d002_20180627000003.xml',
#  '삼성전자_d002_20160105000048.xml',
#  '삼성전자_d002_20200925000359.xml',
#  '삼성전자_d002_20220706000082.xml',
#  '삼성전자_d002_20210521000249.xml',
#  '삼성전자_d002_20201204000157.xml',
#  '삼성전자_d002_20170105000052.xml',
#  '삼성전자_d002_20210507000833.xml',
#  '삼성전자_d002_20220404002302.xml',
#  '삼성전자_d002_20180206000135.xml',
#  '삼성전자_d002_20181217000277.xml',
#  '삼성전자_d002_20210512000475.xml',
#  '삼성전자_d002_20180209000001.xml',
#  '삼성전자_d002_20201215000004.xml',
#  '삼성전자_d002_20210805000005.xml',
#  '삼성전자_d002_20211216000002.xml',
#  '삼성전자_d002_20200417000340.xml',
#  '삼성전자_d002_20220511000108.xml',
#  '삼성전자_d002_20180103000001.xml',
#  '삼성전자_d002_20171122000133.xml',
#  '삼성전자_d002_20180614000405.xml',
#  '삼성전자_d002_20150115000233.xml',
#  '삼성전자_d002_20180510002594.xml',
#  '삼성전자_d002_20180529000335.xml',
#  '삼성전자_d002_20210518000199.xml',
#  '삼성전자_d002_20180104000061.xml',
#  '삼성전자_d002_20221024000053.xml',
#  '삼성전자_d002_20200221001582.xml',
#  '삼성전자_d002_20220415000293.xml',
#  '삼성전자_d002_20211217000105.xml',
#  '삼성전자_d002_20220203000098.xml',
#  '삼성전자_d002_20151209000049.xml',
#  '삼성전자_d002_20200904000162.xml',
#  '삼성전자_d002_20211216000416.xml',
#  '삼성전자_d002_20210107000257.xml',
#  '삼성전자_d002_20211229000706.xml',
#  '삼성전자_d002_20180529000080.xml',
#  '삼성전자_d002_20180611000152.xml',
#  '삼성전자_d002_20180608000025.xml',
#  '삼성전자_d002_20200325000311.xml',
#  '삼성전자_d002_20200908000076.xml',
#  '삼성전자_d002_20200729000093.xml',
#  '삼성전자_d002_20200409002508.xml',
#  '삼성전자_d002_20160816001241.xml',
#  '삼성전자_d002_20180531002185.xml',
#  '삼성전자_d002_20151211000001.xml',
#  '삼성전자_d002_20201209000352.xml',
#  '삼성전자_d002_20181214000333.xml',
#  '삼성전자_d002_20151218000244.xml',
#  '삼성전자_d002_20160707000087.xml',
#  '삼성전자_d002_20180611000379.xml',
#  '삼성전자_d002_20190102000243.xml',
#  '삼성전자_d002_20151208000163.xml',
#  '삼성전자_d002_20150113000037.xml',
#  '삼성전자_d002_20151217000359.xml',
#  '삼성전자_d002_20151209000060.xml',
#  '삼성전자_d002_20210504000590.xml',
#  '삼성전자_d002_20211229000707.xml',
#  '삼성전자_d002_20210503000523.xml',
#  '삼성전자_d002_20220511000290.xml',
#  '삼성전자_d002_20190517000061.xml',
#  '삼성전자_d002_20180611000190.xml',
#  '삼성전자_d002_20201229000053.xml',
#  '삼성전자_d002_20180612000211.xml',
#  '삼성전자_d002_20151209000100.xml',
#  '삼성전자_d002_20160726000657.xml',
#  '삼성전자_d002_20180104000276.xml',
#  '삼성전자_d002_20180531001089.xml',
#  '삼성전자_d002_20210820000092.xml',
#  '삼성전자_d002_20171228000650.xml',
#  '삼성전자_d002_20200130000150.xml',
#  '삼성전자_d002_20170320000027.xml',
#  '삼성전자_d002_20180605000153.xml',
#  '삼성전자_d002_20161205000213.xml',
#  '삼성전자_d002_20191002000438.xml',
#  '삼성전자_d002_20220420000442.xml',
#  '삼성전자_d002_20191227000299.xml',
#  '삼성전자_d002_20190805000185.xml',
#  '삼성전자_d002_20200703000068.xml',
#  '삼성전자_d002_20211213000154.xml',
#  '삼성전자_d002_20180604000046.xml',
#  '삼성전자_d002_20201230000287.xml',
#  '삼성전자_d002_20180601000101.xml',
#  '삼성전자_d002_20180517000119.xml',
#  '삼성전자_d002_20220429001094.xml',
#  '삼성전자_d002_20160629000323.xml',
#  '삼성전자_d002_20190524000105.xml',
#  '삼성전자_d002_20210507000808.xml',
#  '삼성전자_d002_20220628000109.xml',
#  '삼성전자_d002_20180515001495.xml',
#  '삼성전자_d002_20200102000241.xml',
#  '삼성전자_d002_20211215000019.xml',
#  '삼성전자_d002_20161220000136.xml',
#  '삼성전자_d002_20211216000401.xml',
#  '삼성전자_d002_20210629000190.xml',
#  '삼성전자_d002_20180105000015.xml',
#  '삼성전자_d002_20150127000094.xml',
#  '삼성전자_d002_20150128000163.xml',
#  '삼성전자_d002_20220621000006.xml',
#  '삼성전자_d002_20220406000020.xml',
#  '삼성전자_d002_20200220001093.xml',
#  '삼성전자_d002_20210402001357.xml',
#  '삼성전자_d002_20180604000127.xml',
#  '삼성전자_d002_20210223000189.xml',
#  '삼성전자_d002_20201217000257.xml',
#  '삼성전자_d002_20210325000651.xml',
#  '삼성전자_d002_20190830001500.xml',
#  '삼성전자_d002_20151207000295.xml',
#  '삼성전자_d002_20220616000051.xml',
#  '삼성전자_d002_20180611000178.xml',
#  '삼성전자_d002_20170608000073.xml',
#  '삼성전자_d002_20220503000733.xml',
#  '삼성전자_d002_20180515000173.xml',
#  '삼성전자_d002_20161014000174.xml',
#  '삼성전자_d002_20211214000457.xml',
#  '삼성전자_d002_20210820000091.xml',
#  '삼성전자_d002_20180518000038.xml',
#  '삼성전자_d002_20220103000348.xml',
#  '삼성전자_d002_20211220000390.xml',
#  '삼성전자_d002_20170113000407.xml',
#  '삼성전자_d002_20150312000300.xml',
#  '삼성전자_d002_20151208000014.xml',
#  '삼성전자_d002_20161229000038.xml',
#  '삼성전자_d002_20150122000059.xml',
#  '삼성전자_d002_20190107000200.xml',
#  '삼성전자_d002_20190723000287.xml',
#  '삼성전자_d002_20161230000114.xml',
#  '삼성전자_d002_20180601000167.xml',
#  '삼성전자_d002_20221024000036.xml',
#  '삼성전자_d002_20210730000206.xml',
#  '삼성전자_d002_20201210000122.xml',
#  '삼성전자_d002_20220530000626.xml',
#  '삼성전자_d002_20191223000332.xml',
#  '삼성전자_d002_20180525000318.xml',
#  '삼성전자_d002_20170516000410.xml',
#  '삼성전자_d002_20180601000205.xml',
#  '삼성전자_d002_20200129000321.xml',
#  '삼성전자_d002_20211229000213.xml',
#  '삼성전자_d002_20160720000185.xml',
#  '삼성전자_d002_20151211000058.xml',
#  '삼성전자_d002_20190111000478.xml',
#  '삼성전자_d002_20151216000001.xml',
#  '삼성전자_d002_20200128000035.xml',
#  '삼성전자_d002_20170727000111.xml',
#  '삼성전자_d002_20211129000088.xml',
#  '삼성전자_d002_20210518000089.xml',
#  '삼성전자_d002_20211029000179.xml',
#  '삼성전자_d002_20180510001364.xml',
#  '삼성전자_d002_20180524000018.xml',
#  '삼성전자_d002_20220613000158.xml',
#  '삼성전자_d002_20190129000254.xml',
#  '삼성전자_d002_20220531002443.xml',
#  '삼성전자_d002_20220526000116.xml',
#  '삼성전자_d002_20180607000029.xml',
#  '삼성전자_d002_20150217000307.xml',
#  '삼성전자_d002_20170322000388.xml',
#  '삼성전자_d002_20220509000450.xml',
#  '삼성전자_d002_20220708000604.xml',
#  '삼성전자_d002_20190830001189.xml',
#  '삼성전자_d002_20180607000571.xml',
#  '삼성전자_d002_20200130000451.xml',
#  '삼성전자_d002_20170102000336.xml',
#  '삼성전자_d002_20180601000164.xml',
#  '삼성전자_d002_20191022000005.xml',
#  '삼성전자_d002_20181212000385.xml',
#  '삼성전자_d002_20180524000152.xml',
#  '삼성전자_d002_20210629000122.xml',
#  '삼성전자_d002_20201210000041.xml',
#  '삼성전자_d002_20201014000178.xml',
#  '삼성전자_d002_20200120000167.xml',
#  '삼성전자_d002_20220411001018.xml',
#  '삼성전자_d002_20180430000060.xml',
#  '삼성전자_d002_20220530000209.xml',
#  '삼성전자_d002_20201211000142.xml',
#  '삼성전자_d002_20180608000527.xml',
#  '삼성전자_d002_20160824000203.xml',
#  '삼성전자_d002_20201109000178.xml',
#  '삼성전자_d002_20201210000530.xml',
#  '삼성전자_d002_20160802000064.xml',
#  '삼성전자_d002_20151106000141.xml',
#  '삼성전자_d002_20180615000159.xml',
#  '삼성전자_d002_20200130000240.xml',
#  '삼성전자_d002_20170309000919.xml',
#  '삼성전자_d002_20210902000252.xml',
#  '삼성전자_d002_20160721000084.xml',
#  '삼성전자_d002_20211215000121.xml',
#  '삼성전자_d002_20180611000109.xml',
#  '삼성전자_d002_20180611000121.xml',
#  '삼성전자_d002_20200110000140.xml',
#  '삼성전자_d002_20161004000380.xml',
#  '삼성전자_d002_20200416000397.xml',
#  '삼성전자_d002_20191008000149.xml',
#  '삼성전자_d002_20201030000605.xml',
#  '삼성전자_d002_20180601000159.xml',
#  '삼성전자_d002_20200407000777.xml',
#  '삼성전자_d002_20220513000706.xml',
#  '삼성전자_d002_20200910000475.xml',
#  '삼성전자_d002_20220503000342.xml',
#  '삼성전자_d002_20210510000900.xml',
#  '삼성전자_d002_20200130000456.xml',
#  '삼성전자_d002_20220712000224.xml',
#  '삼성전자_d002_20170622000201.xml',
#  '삼성전자_d002_20160609000043.xml',
#  '삼성전자_d002_20180601000149.xml',
#  '삼성전자_d002_20180102000159.xml',
#  '삼성전자_d002_20181120000221.xml',
#  '삼성전자_d002_20200605000261.xml',
#  '삼성전자_d002_20181231000077.xml',
#  '삼성전자_d002_20180611000045.xml',
#  '삼성전자_d002_20180619000101.xml',
#  '삼성전자_d002_20201012000026.xml',
#  '삼성전자_d002_20180518000105.xml',
#  '삼성전자_d002_20160406000142.xml',
#  '삼성전자_d002_20220908000234.xml',
#  '삼성전자_d002_20201210000534.xml',
#  '삼성전자_d002_20200923000517.xml',
#  '삼성전자_d002_20180329000644.xml',
#  '삼성전자_d002_20180611000454.xml',
#  '삼성전자_d002_20210603000241.xml',
#  '삼성전자_d002_20150122000159.xml',
#  '삼성전자_d002_20170322000239.xml',
#  '삼성전자_d002_20201214000001.xml',
#  '삼성전자_d002_20161130001322.xml',
#  '삼성전자_d002_20220324000535.xml',
#  '삼성전자_d002_20210901000049.xml',
#  '삼성전자_d002_20200914000226.xml',
#  '삼성전자_d002_20200603000065.xml',
#  '삼성전자_d002_20180605000044.xml',
#  '삼성전자_d002_20180716000264.xml',
#  '삼성전자_d002_20180608000655.xml',
#  '삼성전자_d002_20180509002697.xml',
#  '삼성전자_d002_20200330000728.xml',
#  '삼성전자_d002_20220608000056.xml',
#  '삼성전자_d002_20201109000021.xml',
#  '삼성전자_d002_20200102000022.xml',
#  '삼성전자_d002_20200103000451.xml',
#  '삼성전자_d002_20170525000001.xml',
#  '삼성전자_d002_20180510003830.xml',
#  '삼성전자_d002_20201215000506.xml',
#  '삼성전자_d002_20201208000184.xml',
#  '삼성전자_d002_20220504000443.xml',
#  '삼성전자_d002_20200107000417.xml',
#  '삼성전자_d002_20210423000610.xml',
#  '삼성전자_d002_20201215000074.xml',
#  '삼성전자_d002_20160114000157.xml',
#  '삼성전자_d002_20220506000004.xml',
#  '삼성전자_d002_20190208000342.xml',
#  '삼성전자_d002_20180612000489.xml',
#  '삼성전자_d002_20210208000166.xml',
#  '삼성전자_d002_20201231000250.xml',
#  '삼성전자_d002_20211217000005.xml',
#  '삼성전자_d002_20180103000105.xml',
#  '삼성전자_d002_20171108000185.xml',
#  '삼성전자_d002_20211214000019.xml',
#  '삼성전자_d002_20180601000002.xml',
#  '삼성전자_d002_20151210000407.xml',
#  '삼성전자_d002_20191227000400.xml',
#  '삼성전자_d002_20180611000319.xml',
#  '삼성전자_d002_20191223000108.xml',
#  '삼성전자_d002_20180514002604.xml',
#  '삼성전자_d002_20211215000480.xml',
#  '삼성전자_d002_20220803000274.xml',
#  '삼성전자_d002_20200722000141.xml',
#  '삼성전자_d002_20220209000061.xml',
#  '삼성전자_d002_20220527000399.xml',
#  '삼성전자_d002_20180601000215.xml',
#  '삼성전자_d002_20160714000478.xml',
#  '삼성전자_d002_20220621000299.xml',
#  '삼성전자_d002_20151201000024.xml',
#  '삼성전자_d002_20151208000261.xml',
#  '삼성전자_d002_20201215000061.xml',
#  '삼성전자_d002_20211215000523.xml',
#  '삼성전자_d002_20180601000177.xml',
#  '삼성전자_d002_20200205000546.xml',
#  '삼성전자_d002_20180607000223.xml',
#  '삼성전자_d002_20170626000048.xml',
#  '삼성전자_d002_20180601000185.xml',
#  '삼성전자_d002_20151210000224.xml',
#  '삼성전자_d002_20170822000003.xml',
#  '삼성전자_d002_20150224000123.xml',
#  '삼성전자_d002_20210517001888.xml',
#  '삼성전자_d002_20180607000021.xml',
#  '삼성전자_d002_20210208000022.xml',
#  '삼성전자_d002_20180515000914.xml',
#  '삼성전자_d002_20180611000076.xml',
#  '삼성전자_d002_20151208000244.xml',
#  '삼성전자_d002_20191226000283.xml',
#  '삼성전자_d002_20181212000210.xml',
#  '삼성전자_d002_20200609000018.xml',
#  '삼성전자_d002_20210514000624.xml',
#  '삼성전자_d002_20151210000152.xml',
#  '삼성전자_d002_20180601000230.xml',
#  '삼성전자_d002_20211215000116.xml',
#  '삼성전자_d002_20201217000239.xml',
#  '삼성전자_d002_20191105000107.xml',
#  '삼성전자_d002_20180608000288.xml',
#  '삼성전자_d002_20210518000081.xml',
#  '삼성전자_d002_20220510000499.xml',
#  '삼성전자_d002_20171227000330.xml',
#  '삼성전자_d002_20200305000097.xml',
#  '삼성전자_d002_20180504001782.xml',
#  '삼성전자_d002_20180627000254.xml',
#  '삼성전자_d002_20220509000505.xml',
#  '삼성전자_d002_20160105000586.xml',
#  '삼성전자_d002_20200128000028.xml',
#  '삼성전자_d002_20201231000063.xml',
#  '삼성전자_d002_20220719000004.xml',
#  '삼성전자_d002_20180427001235.xml',
#  '삼성전자_d002_20180604000389.xml',
#  '삼성전자_d002_20220614000121.xml',
#  '삼성전자_d002_20190612000515.xml',
#  '삼성전자_d002_20180504002116.xml',
#  '삼성전자_d002_20181211000147.xml',
#  '삼성전자_d002_20220513001176.xml',
#  '삼성전자_d002_20200715000053.xml',
#  '삼성전자_d002_20170308000555.xml',
#  '삼성전자_d002_20210305000674.xml',
#  '삼성전자_d002_20151208000084.xml',
#  '삼성전자_d002_20200408002060.xml',
#  '삼성전자_d002_20180523000473.xml',
#  '삼성전자_d002_20211216000096.xml',
#  '삼성전자_d002_20211216000069.xml',
#  '삼성전자_d002_20190516000050.xml',
#  '삼성전자_d002_20220817000246.xml',
#  '삼성전자_d002_20220516002704.xml',
#  '삼성전자_d002_20160216000020.xml',
#  '삼성전자_d002_20180102000169.xml',
#  '삼성전자_d002_20161123000041.xml',
#  '삼성전자_d002_20180612000243.xml',
#  '삼성전자_d002_20151208000247.xml',
#  '삼성전자_d002_20191230000200.xml',
#  '삼성전자_d002_20160415000512.xml',
#  '삼성전자_d002_20220520000324.xml',
#  '삼성전자_d002_20180611000115.xml',
#  '삼성전자_d002_20190107000197.xml',
#  '삼성전자_d002_20200707000122.xml',
#  '삼성전자_d002_20181105000308.xml',
#  '삼성전자_d002_20150429000380.xml',
#  '삼성전자_d002_20210901000285.xml',
#  '삼성전자_d002_20211214000002.xml',
#  '삼성전자_d002_20211216000109.xml',
#  '삼성전자_d002_20160516000824.xml',
#  '삼성전자_d002_20210511000205.xml',
#  '삼성전자_d002_20180608000513.xml',
#  '삼성전자_d002_20191231000470.xml',
#  '삼성전자_d002_20220222002179.xml',
#  '삼성전자_d002_20190116000364.xml',
#  '삼성전자_d002_20201218000643.xml',
#  '삼성전자_d002_20180511001735.xml',
#  '삼성전자_d002_20200410003280.xml',
#  '삼성전자_d002_20151207000206.xml',
#  '삼성전자_d002_20201231000262.xml',
#  '삼성전자_d002_20220712000611.xml',
#  '삼성전자_d002_20180529000005.xml',
#  '삼성전자_d002_20210517000438.xml',
#  '삼성전자_d002_20211215000074.xml',
#  '삼성전자_d002_20210811000133.xml',
#  '삼성전자_d002_20181214000017.xml',
#  '삼성전자_d002_20200904000044.xml',
#  '삼성전자_d002_20191224000201.xml',
#  '삼성전자_d002_20200630000669.xml',
#  '삼성전자_d002_20191122000301.xml',
#  '삼성전자_d002_20171227000092.xml',
#  '삼성전자_d002_20220617000062.xml',
#  '삼성전자_d002_20200618000377.xml',
#  '삼성전자_d002_20180604000003.xml',
#  '삼성전자_d002_20210309000549.xml',
#  '삼성전자_d002_20180529000439.xml',
#  '삼성전자_d002_20220428000592.xml',
#  '삼성전자_d002_20180612000093.xml',
#  '삼성전자_d002_20191217000015.xml',
#  '삼성전자_d002_20210524000002.xml',
#  '삼성전자_d002_20220906000381.xml',
#  '삼성전자_d002_20180529000149.xml',
#  '삼성전자_d002_20171228000607.xml',
#  '삼성전자_d002_20180717000031.xml',
#  '삼성전자_d002_20200210000260.xml',
#  '삼성전자_d002_20220928000075.xml',
#  '삼성전자_d002_20151207000202.xml',
#  '삼성전자_d002_20150320001007.xml',
#  '삼성전자_d002_20201231000272.xml',
#  '삼성전자_d002_20150115000107.xml',
#  '삼성전자_d002_20211001000125.xml',
#  '삼성전자_d002_20180510001430.xml',
#  '삼성전자_d002_20180105000040.xml',
#  '삼성전자_d002_20220525000070.xml',
#  '삼성전자_d002_20180608000259.xml',
#  '삼성전자_d002_20191120000186.xml',
#  '삼성전자_d002_20180611000461.xml',
#  '삼성전자_d002_20180214000001.xml',
#  '삼성전자_d002_20151208000121.xml',
#  '삼성전자_d002_20220405002497.xml',
#  '삼성전자_d002_20220511000013.xml',
#  '삼성전자_d002_20150128000123.xml',
#  '삼성전자_d002_20171227000646.xml',
#  '삼성전자_d002_20180611000111.xml',
#  '삼성전자_d002_20201230000172.xml',
#  '삼성전자_d002_20180601000419.xml',
#  '삼성전자_d002_20180525000262.xml',
#  '삼성전자_d002_20210531001381.xml',
#  '삼성전자_d002_20211216000290.xml',
#  '삼성전자_d002_20211217000350.xml',
#  '삼성전자_d002_20180601000169.xml',
#  '삼성전자_d002_20180608000304.xml',
#  '삼성전자_d002_20200520000263.xml',
#  '삼성전자_d002_20180601000155.xml',
#  '삼성전자_d002_20220318000036.xml',
#  '삼성전자_d002_20190426000140.xml',
#  '삼성전자_d002_20211013000057.xml',
#  '삼성전자_d002_20191227000581.xml',
#  '삼성전자_d002_20151208000082.xml',
#  '삼성전자_d002_20220502000705.xml',
#  '삼성전자_d002_20220125000385.xml',
#  '삼성전자_d002_20211216000090.xml',
#  '삼성전자_d002_20210319000132.xml',
#  '삼성전자_d002_20220110000025.xml',
#  '삼성전자_d002_20190723000260.xml',
#  '삼성전자_d002_20180607000024.xml',
#  '삼성전자_d002_20160829000144.xml',
#  '삼성전자_d002_20180529000189.xml',
#  '삼성전자_d002_20210806000289.xml',
#  '삼성전자_d002_20160615000327.xml',
#  '삼성전자_d002_20170308000182.xml',
#  '삼성전자_d002_20181213000128.xml',
#  '삼성전자_d002_20180601000221.xml',
#  '삼성전자_d002_20170308000155.xml',
#  '삼성전자_d002_20190814001161.xml',
#  '삼성전자_d002_20180718000066.xml',
#  '삼성전자_d002_20180611000113.xml',
#  '삼성전자_d002_20180531001432.xml',
#  '삼성전자_d002_20220207000089.xml',
#  '삼성전자_d002_20151002000005.xml',
#  '삼성전자_d002_20211214000004.xml',
#  '삼성전자_d002_20210430000481.xml',
#  '삼성전자_d002_20200604000221.xml',
#  '삼성전자_d002_20180711000034.xml',
#  '삼성전자_d002_20180111000320.xml',
#  '삼성전자_d002_20180607000192.xml',
#  '삼성전자_d002_20160729000118.xml',
#  '삼성전자_d002_20180607000145.xml',
#  '삼성전자_d002_20160107000067.xml',
#  '삼성전자_d002_20201008000224.xml',
#  '삼성전자_d002_20170308000008.xml',
#  '삼성전자_d002_20191227000031.xml',
#  '삼성전자_d002_20180601000432.xml',
#  '삼성전자_d002_20191230000401.xml',
#  '삼성전자_d002_20210430001364.xml',
#  '삼성전자_d002_20171207000394.xml',
#  '삼성전자_d002_20211214000171.xml',
#  '삼성전자_d002_20190701000283.xml',
#  '삼성전자_d002_20201210000463.xml',
#  '삼성전자_d002_20220511000825.xml',
#  '삼성전자_d002_20180601000195.xml',
#  '삼성전자_d002_20220513000008.xml',
#  '삼성전자_d002_20220315000045.xml',
#  '삼성전자_d002_20220315000051.xml',
#  '삼성전자_d002_20201029000242.xml',
#  '삼성전자_d002_20220708000690.xml',
#  '삼성전자_d002_20201208000114.xml',
#  '삼성전자_d002_20210809000132.xml',
#  '삼성전자_d002_20210518000155.xml',
#  '삼성전자_d002_20180531002559.xml',
#  '삼성전자_d002_20220207000372.xml',
#  '삼성전자_d002_20180108000152.xml',
#  '삼성전자_d002_20160822000287.xml',
#  '삼성전자_d002_20220311000015.xml',
#  '삼성전자_d002_20180611000001.xml',
#  '삼성전자_d002_20200129000161.xml',
#  '삼성전자_d002_20150129000078.xml',
#  '삼성전자_d002_20221017000310.xml',
#  '삼성전자_d002_20211229000053.xml',
#  '삼성전자_d002_20220707000377.xml',
#  '삼성전자_d002_20210105000353.xml',
#  '삼성전자_d002_20220511000711.xml',
#  '삼성전자_d002_20180608000599.xml',
#  '삼성전자_d002_20180601000079.xml',
#  '삼성전자_d002_20201209000375.xml',
#  '삼성전자_d002_20151208000145.xml',
#  '삼성전자_d002_20220706000249.xml',
#  '삼성전자_d002_20201210000001.xml',
#  '삼성전자_d002_20180611000174.xml',
#  '삼성전자_d002_20180105000024.xml',
#  '삼성전자_d002_20200521000265.xml',
#  '삼성전자_d002_20180515001513.xml',
#  '삼성전자_d002_20180605000028.xml',
#  '삼성전자_d002_20220615000337.xml',
#  '삼성전자_d002_20220429001066.xml',
#  '삼성전자_d002_20180508002511.xml',
#  '삼성전자_d002_20190325001217.xml',
#  '삼성전자_d002_20160108000653.xml',
#  '삼성전자_d002_20200911000084.xml',
#  '삼성전자_d002_20180525000005.xml',
#  '삼성전자_d002_20220405001058.xml',
#  '삼성전자_d002_20151207000104.xml',
#  '삼성전자_d002_20210723000157.xml',
#  '삼성전자_d002_20180530000514.xml',
#  '삼성전자_d002_20220630000199.xml',
#  '삼성전자_d002_20210322000015.xml',
#  '삼성전자_d002_20220802000246.xml',
#  '삼성전자_d002_20200925000543.xml',
#  '삼성전자_d002_20210531000761.xml',
#  '삼성전자_d002_20180605000162.xml',
#  '삼성전자_d002_20210203000324.xml',
#  '삼성전자_d002_20160111000068.xml',
#  '삼성전자_d002_20180611000002.xml',
#  '삼성전자_d002_20220614000034.xml',
#  '삼성전자_d002_20220517000073.xml',
#  '삼성전자_d002_20190529000121.xml',
#  '삼성전자_d002_20170621000266.xml',
#  '삼성전자_d002_20210218000576.xml',
#  '삼성전자_d002_20210507000026.xml',
#  '삼성전자_d002_20180607000109.xml',
#  '삼성전자_d002_20180605000002.xml',
#  '삼성전자_d002_20200914000274.xml',
#  '삼성전자_d002_20180611000162.xml',
#  '삼성전자_d002_20170308000130.xml',
#  '삼성전자_d002_20211215000176.xml',
#  '삼성전자_d002_20170308000124.xml',
#  '삼성전자_d002_20200117000365.xml',
#  '삼성전자_d002_20210303000376.xml',
#  '삼성전자_d002_20191231000412.xml',
#  '삼성전자_d002_20211215000412.xml',
#  '삼성전자_d002_20220530000276.xml',
#  '삼성전자_d002_20180611000349.xml',
#  '삼성전자_d002_20160728000095.xml',
#  '삼성전자_d002_20220512000519.xml',
#  '삼성전자_d002_20201230000302.xml',
#  '삼성전자_d002_20180521000446.xml',
#  '삼성전자_d002_20211216000433.xml',
#  '삼성전자_d002_20191205000129.xml',
#  '삼성전자_d002_20151231000456.xml',
#  '삼성전자_d002_20220513001710.xml',
#  '삼성전자_d002_20200508000096.xml',
#  '삼성전자_d002_20200103000166.xml',
#  '삼성전자_d002_20160718000138.xml',
#  '삼성전자_d002_20220615000308.xml',
#  '삼성전자_d002_20180515001458.xml',
#  '삼성전자_d002_20210811000187.xml',
#  '삼성전자_d002_20220512000647.xml',
#  '삼성전자_d002_20151210000084.xml',
#  '삼성전자_d002_20200406000434.xml',
#  '삼성전자_d002_20220916000201.xml',
#  '삼성전자_d002_20201222000063.xml',
#  '삼성전자_d002_20200107000126.xml',
#  '삼성전자_d002_20211231000394.xml',
#  '삼성전자_d002_20211215000007.xml',
#  '삼성전자_d002_20201209000005.xml',
#  '삼성전자_d002_20210111000382.xml',
#  '삼성전자_d002_20160812000847.xml',
#  '삼성전자_d002_20200805000199.xml',
#  '삼성전자_d002_20150120000213.xml',
#  '삼성전자_d002_20170308000109.xml',
#  '삼성전자_d002_20151210000137.xml',
#  '삼성전자_d002_20201123000073.xml',
#  '삼성전자_d002_20180607000332.xml',
#  '삼성전자_d002_20180607000326.xml',
#  '삼성전자_d002_20220517000314.xml',
#  '삼성전자_d002_20210517001580.xml',
#  '삼성전자_d002_20201210000239.xml',
#  '삼성전자_d002_20211215000364.xml',
#  '삼성전자_d002_20170612000106.xml',
#  '삼성전자_d002_20201104000114.xml',
#  '삼성전자_d002_20200304000324.xml',
#  '삼성전자_d002_20201203000103.xml',
#  '삼성전자_d002_20200812000231.xml',
#  '삼성전자_d002_20200828001387.xml',
#  '삼성전자_d002_20200116000276.xml',
#  '삼성전자_d002_20210128000335.xml',
#  '삼성전자_d002_20210823000291.xml',
#  '삼성전자_d002_20200915000005.xml',
#  '삼성전자_d002_20180514001984.xml',
#  '삼성전자_d002_20220418000267.xml',
#  '삼성전자_d002_20150813000161.xml',
#  '삼성전자_d002_20220512000656.xml',
#  '삼성전자_d002_20181213000015.xml',
#  '삼성전자_d002_20211214000105.xml',
#  '삼성전자_d002_20200828000462.xml',
#  '삼성전자_d002_20210316000067.xml',
#  '삼성전자_d002_20160722000197.xml',
#  '삼성전자_d002_20220415000066.xml',
#  '삼성전자_d002_20220404001388.xml',
#  '삼성전자_d002_20171229000002.xml',
#  '삼성전자_d002_20201230000503.xml',
#  '삼성전자_d002_20180528000002.xml',
#  '삼성전자_d002_20211224000479.xml',
#  '삼성전자_d002_20171220000247.xml',
#  '삼성전자_d002_20180604000098.xml',
#  '삼성전자_d002_20190125000514.xml',
#  '삼성전자_d002_20180525000029.xml',
#  '삼성전자_d002_20180525000001.xml',
#  '삼성전자_d002_20200204000348.xml',
#  '삼성전자_d002_20170511004047.xml',
#  '삼성전자_d002_20180514005276.xml',
#  '삼성전자_d002_20150114000306.xml',
#  '삼성전자_d002_20210202000037.xml',
#  '삼성전자_d002_20180206000107.xml',
#  '삼성전자_d002_20160725000456.xml',
#  '삼성전자_d002_20211214000305.xml',
#  '삼성전자_d002_20180518000024.xml',
#  '삼성전자_d002_20201210000159.xml',
#  '삼성전자_d002_20151215000073.xml',
#  '삼성전자_d002_20161229000391.xml',
#  '삼성전자_d002_20210105000430.xml',
#  '삼성전자_d002_20161229000352.xml',
#  '삼성전자_d002_20160727000373.xml',
#  '삼성전자_d002_20220207000015.xml',
#  '삼성전자_d002_20190311000580.xml',
#  '삼성전자_d002_20190613000288.xml',
#  '삼성전자_d002_20211216000144.xml',
#  '삼성전자_d002_20151204000295.xml',
#  '삼성전자_d002_20220111000233.xml',
#  '삼성전자_d002_20200929001148.xml',
#  '삼성전자_d002_20220921000127.xml',
#  '삼성전자_d002_20180608000238.xml',
#  '삼성전자_d002_20180521000332.xml',
#  '삼성전자_d002_20150427000112.xml',
#  '삼성전자_d002_20220427000216.xml',
#  '삼성전자_d002_20201230000310.xml',
#  '삼성전자_d002_20180605000207.xml',
#  '삼성전자_d002_20180508002879.xml',
#  '삼성전자_d002_20220429001117.xml',
#  '삼성전자_d002_20211216000435.xml',
#  '삼성전자_d002_20220627000141.xml',
#  '삼성전자_d002_20160304000429.xml',
#  '삼성전자_d002_20180607000046.xml',
#  '삼성전자_d002_20180529000100.xml',
#  '삼성전자_d002_20161212000198.xml',
#  '삼성전자_d002_20201118000053.xml',
#  '삼성전자_d002_20210803000179.xml',
#  '삼성전자_d002_20180604000099.xml',
#  '삼성전자_d002_20190729000265.xml',
#  '삼성전자_d002_20201211000098.xml']

# %%
from typing import *

def load_report(filename:str) -> BeautifulSoup:
    with open(PATH + filename, 'rb') as f:
        a = f.read()
        bs = BeautifulSoup(a, 'html.parser')
    
    return bs

def get_company_info(bs: BeautifulSoup) -> List :
    tr = bs.find('td', string='회 사 명').parent.parent
    
    # 회사명
    name = tr.find('td', string='회 사 명').next_sibling.next_sibling.text

    # 법인구분
    market = tr.find('td', string='법인구분').next_sibling.next_sibling.text
    market = market.replace('상장법인','')

    # 종목코드
    stock_code = tr.find('td', string='회사코드 ').next_sibling.next_sibling.text

    # 발생주식 총수
    total_stock = tr.find('td', string='발행주식 총수').next_sibling.next_sibling.text
    total_stock = int(total_stock.replace(r',', '').strip())

    return [name, market, stock_code, total_stock]

def get_reporter_info(bs: BeautifulSoup)->List:
    tr = bs.find('td', string='보고구분').parent

    # 보고구분
    report_type = tr.find('td', string='보고구분').next_sibling.next_sibling.text
    
    # 보고자 구분
    reporter_type = tr.find('td', string='보고자 구분').next_sibling.next_sibling.text
    
    tr = bs.find('td', string='성명(명칭)').parent
    
    # 보고자 명칭
    reporter_name = tr.find('td', string='한     글').next_sibling.next_sibling.text
    
    tr = bs.find('td', string='발행회사와의 관계').parent
    
    # 임원
    executive = tr.find('td', string='임원(등기여부)').next_sibling.next_sibling.text
    
    # 직위명
    position = tr.find('td', string='직위명').next_sibling.next_sibling.text
    
    tr = tr.next_sibling.next_sibling.next_sibling.next_sibling
    
    # 주요주주
    # try:
    stock_holder_type = tr.find('td', string='주요주주').next_sibling.next_sibling.text
    # except:
        # stock_holder_type = '-'
    
    return [report_type, reporter_type, reporter_name, executive, position, stock_holder_type]

def get_report_contents(bs: BeautifulSoup) -> List:
    body = bs.find('th', string='보고사유').parent.parent.next_sibling.next_sibling
    
    trs = body.find_all('tr')
    contents = []
    for tr in trs[:-1]:
        tus = tr.find_all('tu')
        
        # 변동사유
        reason = tus[0].text
        
        # 변동일
        change_date = tus[1].text
        
        # 특정증권등의 종류
        stock_type = tus[2].text
        
        tes = tr.find_all('te')
        
        # 변동전
        try:
            prev = tes[0].text
            prev = int(prev.replace(',', '').strip())
        except:
            prev = 0
        
        # 증감
        try:
            change = tes[1].text
            change = int(change.replace(',', '').strip())
        except:
            change = 0
                
        # 변동 후
        try:
            after = tes[2].text
            after = int(after.replace(',', '').strip())
        except:
            after = 0
        
        contents.append([reason, change_date, stock_type, prev, change, after])
        
    return contents

# %%
import re

data = []
for filename in filenames:
    try:
        name, date = re.search(r'([^_]+)_d002_(\d{8})', filename).groups()
        bs = load_report(filename)
        company_info = get_company_info(bs)
        reporter_info = get_reporter_info(bs)
        contents = get_report_contents(bs)
        
        for content in contents:
            data.append(company_info + reporter_info + content + [name, date])
            
        # break
    except Exception as e:
        print(filename, e)

df = pd.DataFrame(data, columns=['회사명1', '법인구분', '종목코드', '발행주식 총수', '보고구분', '보고자 구분', '보고자 명칭', '임원', '직위명', '주요주주', '변동사유', '변동일', '특정증권등의 종류', '변동전', '증감', '변동후', '회사명2', '보고일자'])
df.shape
# Out:
# /Users/y35-n0/opt/anaconda3/envs/ml_team_project/lib/python3.9/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# 삼성전자_d002_20220802000246.xml 'NoneType' object has no attribute 'parent'
# (2156, 18)

# %%
df.sort_values
df.to_csv('../data/preprocessed/20150101-20221024_삼성전자_d002.csv', encoding='cp949', index=False)

# %% [markdown]
# ## Sample

# %%
with open('../data/origin/dart/reports/d002/네오리진_d002_20210104000195.xml', 'rb') as f:
        a = f.read()
        bs = BeautifulSoup(a, 'html.parser')

# %% [markdown]
# #### 회사 개요

# %%
tr = bs.find('td', string='회 사 명').parent.parent

# %%
# 회사명
tr.find('td', string='회 사 명').next_sibling.next_sibling.text
# Out:
# '주식회사 코닉글로리'

# %%
# 법인구분
market = tr.find('td', string='법인구분').next_sibling.next_sibling.text
market.replace('상장법인','')
# Out:
# '코스닥'

# %%
# 종목코드
tr.find('td', string='회사코드 ').next_sibling.next_sibling.text
# Out:
# '094860'

# %%
# 발생주식 총수
total = tr.find('td', string='발행주식 총수').next_sibling.next_sibling.text
int(total.replace(r',', '').strip())
# Out:
# 50642595

# %% [markdown]
# #### 보고자 개요

# %%
tr = bs.find('td', string='보고구분').parent

# %%
# 보고구분
tr.find('td', string='보고구분').next_sibling.next_sibling.text
# Out:
# '변동'

# %%
# 보고자 구분
tr.find('td', string='보고자 구분').next_sibling.next_sibling.text
# Out:
# '외국법인'

# %%
tr = bs.find('td', string='성명(명칭)').parent

# %%
# 보고자 명칭
tr.find('td', string='한     글').next_sibling.next_sibling.text
# Out:
# '조이프렌즈 피티이 엘티디'

# %%
tr = bs.find('td', string='발행회사와의 관계').parent

# %%
# 임원여부
tr.find('td', string='임원(등기여부)').next_sibling.next_sibling.text
# Out:
# '-'

# %%
# 직위명
tr.find('td', string='직위명').next_sibling.next_sibling.text
# Out:
# '-'

# %%
# tr = tr.next_sibling
# 주요주주
tr.find('td', string='주요주주')#.next_sibling.next_sibling.text

# %%
tr.next_sibling.next_sibling.next_sibling.next_sibling
# Out:
# <tr acopy="Y" adelete="Y">
# <td align="CENTER" aupdatecont="N" height="30" valign="MIDDLE" width="115">주요주주</td>
# <tu align="CENTER" aunit="MAIN_SH" aunitvalue="2" colspan="3" height="30" valign="MIDDLE" width="352">사실상지배주주</tu>
# </tr>

# %% [markdown]
# #### 보고 항목

# %%
body = bs.find('th', string='보고사유').parent.parent.next_sibling.next_sibling

# %%
trs = body.find_all('tr')
tus = trs[0].find_all('tu')

# %%
# 변동사유
tus[0].text
# Out:
# '합병(+)'

# %%
# 변동일
tus[1].text
# Out:
# '2020.12.31'

# %%
# 특정증권등의 종류
tus[2].text
# Out:
# '보통주'

# %%
tes = body.find_all('te')

# %%
# 변동전
tes[0].text
# Out:
# '- '

# %%
# 증감
tes[1].text
# Out:
# '8,471,733 '

# %%
# 변동 후
tes[2].text
# Out:
# '8,471,733 '

# %%
# 취득/처분 단가
tes[3].text
# Out:
# '- '

# %%
# 비고
tes[4].text
# Out:
# '-'

# %% [markdown]
# #### 보고 항목

# %%
body = bs.find('th', string='보고사유').parent.parent.next_sibling.next_sibling

# %%
trs = body.find_all('tr')
tr = trs[1]
tus = tr.find_all('tu')

# %%
# 변동사유
tus[0].text
# Out:
# '장내매수(+)'

# %%
# 변동일
tus[1].text
# Out:
# '2020년 12월 28일'

# %%
# 특정증권등의 종류
tus[2].text
# Out:
# '보통주'

# %%
tes = tr.find_all('te')

# %%
# 변동전
tes[0].text
# Out:
# '2,538,740'

# %%
# 증감
tes[1].text
# Out:
# '130,256'

# %%
# 변동 후
tes[2].text
# Out:
# '2,668,996'

# %%
# 취득/처분 단가
tes[3].text
# Out:
# '2,685'

# %%
# 비고
tes[4].text
# Out:
# '-'

# %%
df['']
